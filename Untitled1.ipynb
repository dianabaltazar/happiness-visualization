# %%
covid_csv = 'owid-covid-data xcl.csv'
schools_csv = 'school-closures-covid xcl.csv'

# %%
import pandas as pd

# %%
covid_df = pd.read_csv(covid_csv)
schools_df = pd.read_csv(schools_csv)
covid_df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  24/02/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  25/02/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  26/02/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  27/02/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  28/02/2020          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 96657      ZWE    Africa     Zimbabwe  14/06/2021      40077.0      118.0
# 96658      ZWE    Africa     Zimbabwe  15/06/2021      40318.0      241.0
# 96659      ZWE    Africa     Zimbabwe  16/06/2021      40556.0      238.0
# 96660      ZWE    Africa     Zimbabwe  17/06/2021      40927.0      371.0
# 96661      ZWE    Africa     Zimbabwe  18/06/2021      41335.0      408.0
#
#        total_deaths  new_deaths  total_cases_per_million  \
# ...

# %%
covid_df.columns

# %%
coviddf = pd.DataFrame(covid_df)
schoolsdf = pd.DataFrame(schools_df)

# %%
schoolsdf[schoolsdf['Day']=='/1/12/2020']
# Out:
#             Entity Code         Day  school_closures
# 327    Afghanistan  AFG  /1/12/2020                1
# 328    Afghanistan  AFG  /1/12/2020                1
# 329    Afghanistan  AFG  /1/12/2020                1
# 330    Afghanistan  AFG  /1/12/2020                1
# 331    Afghanistan  AFG  /1/12/2020                1
# ...            ...  ...         ...              ...
# 93707     Zimbabwe  ZWE  /1/12/2020                1
# 93708     Zimbabwe  ZWE  /1/12/2020                1
# 93709     Zimbabwe  ZWE  /1/12/2020                1
# 93710     Zimbabwe  ZWE  /1/12/2020                1
# 93711     Zimbabwe  ZWE  /1/12/2020                1
#
# [1295 rows x 4 columns]

# %%
for i in schoolsdf:
    if schoolsdf['Day'][0] == '/1':
        schoolsdf['Day'] =
