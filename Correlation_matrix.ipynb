# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### IMPORT DATA

# %%
data = pd.read_csv('data/owid-covid-data.csv')
data
# Out:
#       iso_code continent     location       date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1          AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
# ...        ...       ...          ...        ...          ...        ...
# 87945      ZWE    Africa     Zimbabwe   5/8/2021      38414.0       11.0
# 87946      ZWE    Africa     Zimbabwe   5/9/2021      38419.0        5.0
# 87947      ZWE    Africa     Zimbabwe  5/10/2021      38433.0       14.0
# 87948      ZWE    Africa     Zimbabwe  5/11/2021      38448.0       15.0
# 87949      ZWE    Africa     Zimbabwe  5/12/2021      38466.0       18.0
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 0               NaN         NaN                    0.026
# 1               NaN         NaN                    0.026
# 2               NaN         NaN                    0.026
# 3               NaN         NaN                    0.026
# 4               NaN         NaN                    0.026
# ...             ...         ...                      ...
# 87945        1576.0         0.0                 2584.551
# 87946        1576.0         0.0                 2584.888
# 87947        1576.0         0.0                 2585.830
# 87948        1579.0         3.0                 2586.839
# 87949        1579.0         0.0                 2588.050
#
#        new_cases_per_million  ...  median_age  aged_65_older  aged_70_older  \
# 0                      0.026  ...        18.6          2.581          1.337
# 1                      0.000  ...        18.6          2.581          1.337
# 2                      0.000  ...        18.6          2.581          1.337
# 3                      0.000  ...        18.6          2.581          1.337
# 4                      0.000  ...        18.6          2.581          1.337
# ...                      ...  ...         ...            ...            ...
# 87945                  0.740  ...        19.6          2.822          1.882
# 87946                  0.336  ...        19.6          2.822          1.882
# 87947                  0.942  ...        19.6          2.822          1.882
# 87948                  1.009  ...        19.6          2.822          1.882
# 87949                  1.211  ...        19.6          2.822          1.882
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 87945        1899.775             21.4                307.846
# 87946        1899.775             21.4                307.846
# 87947        1899.775             21.4                307.846
# 87948        1899.775             21.4                307.846
# 87949        1899.775             21.4                307.846
#
#        diabetes_prevalence  hospital_beds_per_thousand  life_expectancy  \
# 0                     9.59                         0.5            64.83
# 1                     9.59                         0.5            64.83
# 2                     9.59                         0.5            64.83
# 3                     9.59                         0.5            64.83
# 4                     9.59                         0.5            64.83
# ...                    ...                         ...              ...
# 87945                 1.82                         1.7            61.49
# 87946                 1.82                         1.7            61.49
# 87947                 1.82                         1.7            61.49
# 87948                 1.82                         1.7            61.49
# 87949                 1.82                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 87945                    0.571
# 87946                    0.571
# 87947                    0.571
# 87948                    0.571
# 87949                    0.571
#
# [87950 rows x 40 columns]

# %% [markdown]
# ### SELECT ROWS

# %%
df_small = data[['iso_code',
'continent',
'location',
'date',
'total_cases_per_million',
'new_cases_per_million',
'total_deaths_per_million',
'new_deaths_per_million',
'hosp_patients_per_million',
'total_tests_per_thousand',
'new_tests_per_thousand',
'positive_rate',
'people_vaccinated',
'population',
'population_density',
'median_age',
'aged_70_older',
'gdp_per_capita',
'hospital_beds_per_thousand',
'life_expectancy']]
df_small
# Out:
#       iso_code continent     location       date  total_cases_per_million  \
# 0          AFG      Asia  Afghanistan  2/24/2020                    0.026
# 1          AFG      Asia  Afghanistan  2/25/2020                    0.026
# 2          AFG      Asia  Afghanistan  2/26/2020                    0.026
# 3          AFG      Asia  Afghanistan  2/27/2020                    0.026
# 4          AFG      Asia  Afghanistan  2/28/2020                    0.026
# ...        ...       ...          ...        ...                      ...
# 87945      ZWE    Africa     Zimbabwe   5/8/2021                 2584.551
# 87946      ZWE    Africa     Zimbabwe   5/9/2021                 2584.888
# 87947      ZWE    Africa     Zimbabwe  5/10/2021                 2585.830
# 87948      ZWE    Africa     Zimbabwe  5/11/2021                 2586.839
# 87949      ZWE    Africa     Zimbabwe  5/12/2021                 2588.050
#
#        new_cases_per_million  total_deaths_per_million  \
# 0                      0.026                       NaN
# 1                      0.000                       NaN
# 2                      0.000                       NaN
# 3                      0.000                       NaN
# 4                      0.000                       NaN
# ...                      ...                       ...
# 87945                  0.740                   106.036
# 87946                  0.336                   106.036
# 87947                  0.942                   106.036
# 87948                  1.009                   106.237
# 87949                  1.211                   106.237
#
#        new_deaths_per_million  hosp_patients_per_million  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 87945                   0.000                        NaN
# 87946                   0.000                        NaN
# 87947                   0.000                        NaN
# 87948                   0.202                        NaN
# 87949                   0.000                        NaN
#
#        total_tests_per_thousand  new_tests_per_thousand  positive_rate  \
# 0                           NaN                     NaN            NaN
# 1                           NaN                     NaN            NaN
# 2                           NaN                     NaN            NaN
# 3                           NaN                     NaN            NaN
# 4                           NaN                     NaN            NaN
# ...                         ...                     ...            ...
# 87945                    34.229                   0.119          0.011
# 87946                    34.317                   0.087          0.010
# 87947                       NaN                     NaN            NaN
# 87948                       NaN                     NaN            NaN
# 87949                       NaN                     NaN            NaN
#
#        people_vaccinated  population  population_density  median_age  \
# 0                    NaN   38.928341              54.422        18.6
# 1                    NaN   38.928341              54.422        18.6
# 2                    NaN   38.928341              54.422        18.6
# 3                    NaN   38.928341              54.422        18.6
# 4                    NaN   38.928341              54.422        18.6
# ...                  ...         ...                 ...         ...
# 87945           509274.0   14.862927              42.729        19.6
# 87946           526066.0   14.862927              42.729        19.6
# 87947           529360.0   14.862927              42.729        19.6
# 87948           539526.0   14.862927              42.729        19.6
# 87949                NaN   14.862927              42.729        19.6
#
#        aged_70_older  gdp_per_capita  hospital_beds_per_thousand  \
# 0              1.337        1803.987                         0.5
# 1              1.337        1803.987                         0.5
# 2              1.337        1803.987                         0.5
# 3              1.337        1803.987                         0.5
# 4              1.337        1803.987                         0.5
# ...              ...             ...                         ...
# 87945          1.882        1899.775                         1.7
# 87946          1.882        1899.775                         1.7
# 87947          1.882        1899.775                         1.7
# 87948          1.882        1899.775                         1.7
# 87949          1.882        1899.775                         1.7
#
#        life_expectancy
# 0                64.83
# 1                64.83
# 2                64.83
# 3                64.83
# 4                64.83
# ...                ...
# 87945            61.49
# 87946            61.49
# 87947            61.49
# 87948            61.49
# 87949            61.49
#
# [87950 rows x 20 columns]

# %% [markdown]
# ### CREATE CORRELATION HEATMAP

# %%
correlation_mat = df_small.corr()

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(correlation_mat, annot = True)
plt.title("Correlation matrix data")
plt.show()

# %%
correlation_mat = df_small.corr()
corr_pairs = correlation_mat.unstack()

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")
print(sorted_pairs)
# Out:
# hosp_patients_per_million   life_expectancy              -0.297363
# life_expectancy             hosp_patients_per_million    -0.297363
# gdp_per_capita              hosp_patients_per_million    -0.253998
# hosp_patients_per_million   gdp_per_capita               -0.253998
# positive_rate               gdp_per_capita               -0.194839
#                                                             ...
# new_deaths_per_million      new_deaths_per_million        1.000000
# total_deaths_per_million    total_deaths_per_million      1.000000
# new_cases_per_million       new_cases_per_million         1.000000
# hospital_beds_per_thousand  hospital_beds_per_thousand    1.000000
# life_expectancy             life_expectancy               1.000000
# Length: 256, dtype: float64

# %%
strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.6]
print(strong_pairs)
# Out:
# total_cases_per_million     total_tests_per_thousand      0.603519
# total_tests_per_thousand    total_cases_per_million       0.603519
# people_vaccinated           population                    0.616285
# population                  people_vaccinated             0.616285
# gdp_per_capita              median_age                    0.639822
# median_age                  gdp_per_capita                0.639822
# aged_70_older               hospital_beds_per_thousand    0.652346
# hospital_beds_per_thousand  aged_70_older                 0.652346
#                             median_age                    0.661971
# median_age                  hospital_beds_per_thousand    0.661971
# life_expectancy             gdp_per_capita                0.676514
# gdp_per_capita              life_expectancy               0.676514
# hosp_patients_per_million   positive_rate                 0.717025
# positive_rate               hosp_patients_per_million     0.717025
# aged_70_older               life_expectancy               0.718914
# life_expectancy             aged_70_older                 0.718914
# new_tests_per_thousand      total_tests_per_thousand      0.749852
# total_tests_per_thousand    new_tests_per_thousand        0.749852
# new_deaths_per_million      hosp_patients_per_million     0.806810
# hosp_patients_per_million   new_deaths_per_million        0.806810
# total_cases_per_million     total_deaths_per_million      0.846658
# total_deaths_per_million    total_cases_per_million       0.846658
# life_expectancy             median_age                    0.848169
# median_age                  life_expectancy               0.848169
# aged_70_older               median_age                    0.899600
# median_age                  aged_70_older                 0.899600
# total_cases_per_million     total_cases_per_million       1.000000
# gdp_per_capita              gdp_per_capita                1.000000
# aged_70_older               aged_70_older                 1.000000
# median_age                  median_age                    1.000000
# population_density          population_density            1.000000
# population                  population                    1.000000
# people_vaccinated           people_vaccinated             1.000000
# positive_rate               positive_rate                 1.000000
# new_tests_per_thousand      new_tests_per_thousand        1.000000
# total_tests_per_thousand    total_tests_per_thousand      1.000000
# hosp_patients_per_million   hosp_patients_per_million     1.000000
# new_deaths_per_million      new_deaths_per_million        1.000000
# total_deaths_per_million    total_deaths_per_million      1.000000
# new_cases_per_million       new_cases_per_million         1.000000
# hospital_beds_per_thousand  hospital_beds_per_thousand    1.000000
# life_expectancy             life_expectancy               1.000000
# dtype: float64

# %% [markdown]
# ### SELECT NEW VARIABLES

# %%
df_small = data[['iso_code',
'continent',
'location',
'date',
'total_cases_per_million', --------------------
'new_cases_per_million',
'total_deaths_per_million', --------------------
'new_deaths_per_million', =====================
'hosp_patients_per_million', ==================== //////////////////
'total_tests_per_thousand',..........................
'new_tests_per_thousand',............................
'positive_rate', //////////////////
'people_vaccinated',
'population',
'population_density',
'median_age',******************
'aged_70_older',******************
'gdp_per_capita',
'hospital_beds_per_thousand',
'life_expectancy']]******************
df_small

# %% [markdown]
# ### SELECT G5 COUNTRIES

# %%
final_data = df_small[df_small['location'].isin(['Brazil','China','India','Mexico','South Africa'])]
final_data
# Out:
#       iso_code      continent      location       date  \
# 11242      BRA  South America        Brazil  2/26/2020
# 11243      BRA  South America        Brazil  2/27/2020
# 11244      BRA  South America        Brazil  2/28/2020
# 11245      BRA  South America        Brazil  2/29/2020
# 11246      BRA  South America        Brazil   3/1/2020
# ...        ...            ...           ...        ...
# 73064      ZAF         Africa  South Africa   5/8/2021
# 73065      ZAF         Africa  South Africa   5/9/2021
# 73066      ZAF         Africa  South Africa  5/10/2021
# 73067      ZAF         Africa  South Africa  5/11/2021
# 73068      ZAF         Africa  South Africa  5/12/2021
#
#        total_cases_per_million  new_cases_per_million  \
# 11242                    0.005                  0.005
# 11243                    0.005                  0.000
# 11244                    0.005                  0.000
# 11245                    0.009                  0.005
# 11246                    0.009                  0.000
# ...                        ...                    ...
# 73064                26853.164                  0.000
# 73065                26920.085                 66.921
# 73066                26939.121                 19.036
# 73067                26965.222                 26.101
# 73068                27011.741                 46.519
#
#        total_deaths_per_million  new_deaths_per_million  \
# 11242                       NaN                     NaN
# 11243                       NaN                     NaN
# 11244                       NaN                     NaN
# 11245                       NaN                     NaN
# 11246                       NaN                     NaN
# ...                         ...                     ...
# 73064                   922.074                   0.000
# 73065                   922.883                   0.809
# 73066                   924.401                   1.517
# 73067                   925.598                   1.197
# 73068                   926.812                   1.214
#
#        hosp_patients_per_million  total_tests_per_thousand  \
# 11242                        NaN                       NaN
# 11243                        NaN                       NaN
# 11244                        NaN                       NaN
# 11245                        NaN                       NaN
# 11246                        NaN                       NaN
# ...                          ...                       ...
# 73064                        NaN                   183.137
# 73065                        NaN                   183.577
# 73066                        NaN                   183.886
# 73067                        NaN                       NaN
# 73068                        NaN                       NaN
#
#        new_tests_per_thousand  positive_rate  people_vaccinated  population  \
# 11242                     NaN            NaN                NaN  212.559409
# 11243                     NaN            NaN                NaN  212.559409
# 11244                     NaN            NaN                NaN  212.559409
# 11245                     NaN            NaN                NaN  212.559409
# 11246                     NaN            NaN                NaN  212.559409
# ...                       ...            ...                ...         ...
# 73064                   0.504          0.055           382480.0   59.308690
# 73065                   0.440          0.066                NaN   59.308690
# 73066                   0.309          0.067           395230.0   59.308690
# 73067                     NaN            NaN           414372.0   59.308690
# 73068                     NaN            NaN           430730.0   59.308690
#
#        population_density  median_age  aged_70_older  gdp_per_capita  \
# 11242              25.040        33.5          5.060       14103.452
# 11243              25.040        33.5          5.060       14103.452
# 11244              25.040        33.5          5.060       14103.452
# 11245              25.040        33.5          5.060       14103.452
# 11246              25.040        33.5          5.060       14103.452
# ...                   ...         ...            ...             ...
# 73064              46.754        27.3          3.053       12294.876
# 73065              46.754        27.3          3.053       12294.876
# 73066              46.754        27.3          3.053       12294.876
# 73067              46.754        27.3          3.053       12294.876
# 73068              46.754        27.3          3.053       12294.876
#
#        hospital_beds_per_thousand  life_expectancy
# 11242                        2.20            75.88
# 11243                        2.20            75.88
# 11244                        2.20            75.88
# 11245                        2.20            75.88
# 11246                        2.20            75.88
# ...                           ...              ...
# 73064                        2.32            64.13
# 73065                        2.32            64.13
# 73066                        2.32            64.13
# 73067                        2.32            64.13
# 73068                        2.32            64.13
#
# [2347 rows x 20 columns]

# %%
final_data.location.unique()
# Out:
# array(['Brazil', 'China', 'India', 'Mexico', 'South Africa'], dtype=object)
