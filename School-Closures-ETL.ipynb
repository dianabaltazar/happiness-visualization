# %%
import pandas as pd
from sqlalchemy import create_engine
from config import PostgresK
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-a75349b022a3> in <module>
#       1 import pandas as pd
#       2 from sqlalchemy import create_engine
# ----> 3 from config import PostgresK
#
# ModuleNotFoundError: No module named 'config'

# %%
connection_string = f'vpiijrpdtosgpt:{PostgresK}@ec2-54-166-167-192.compute-1.amazonaws.com:5432/d1j88kvbcshh7l'
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['schoolclosuresh', 'coviddatah']

# %%
print(engine)
# Out:
# Engine(postgresql://vpiijrpdtosgpt:***@ec2-54-166-167-192.compute-1.amazonaws.com:5432/d1j88kvbcshh7l)

# %%
pd.read_sql('SELECT * FROM schoolclosuresh', con=engine).head()
# Out:
#        country iso_code       date  school_closures
# 0  Afghanistan      AFG  1/21/2020                0
# 1  Afghanistan      AFG  1/22/2020                0
# 2  Afghanistan      AFG  1/23/2020                0
# 3  Afghanistan      AFG  1/24/2020                0
# 4  Afghanistan      AFG  1/25/2020                0

# %%
pd.read_sql('SELECT * FROM coviddatah', con=engine).head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1      AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2      AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3      AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4      AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
#
#    total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           NaN         NaN                    0.026                  0.026
# 1           NaN         NaN                    0.026                  0.000
# 2           NaN         NaN                    0.026                  0.000
# 3           NaN         NaN                    0.026                  0.000
# 4           NaN         NaN                    0.026                  0.000
#
#    ...  median_age  aged_65_older  aged_70_older  gdp_per_capita  \
# 0  ...        18.6          2.581          1.337        1803.987
# 1  ...        18.6          2.581          1.337        1803.987
# 2  ...        18.6          2.581          1.337        1803.987
# 3  ...        18.6          2.581          1.337        1803.987
# 4  ...        18.6          2.581          1.337        1803.987
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0              NaN                597.029                 9.59
# 1              NaN                597.029                 9.59
# 2              NaN                597.029                 9.59
# 3              NaN                597.029                 9.59
# 4              NaN                597.029                 9.59
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 40 columns]

# %%
pd.read_sql('SELECT cd.*, sc.school_closures FROM coviddatah cd INNER JOIN  schoolclosuresh sc ON  sc.date = cd.date AND sc.iso_code = cd.iso_code',con=engine)
# Out:
#       iso_code continent              location        date  total_cases  \
# 0          AFG      Asia           Afghanistan  10/10/2020      39703.0
# 1          AGO    Africa                Angola  10/10/2020       6246.0
# 2          ALB    Europe               Albania  10/10/2020      15231.0
# 3          AND    Europe               Andorra  10/10/2020       2696.0
# 4          ARE      Asia  United Arab Emirates  10/10/2020     105133.0
# ...        ...       ...                   ...         ...          ...
# 75004      VNM      Asia               Vietnam    9/9/2020       1059.0
# 75005      YEM      Asia                 Yemen    9/9/2020       1999.0
# 75006      ZAF    Africa          South Africa    9/9/2020     642431.0
# 75007      ZMB    Africa                Zambia    9/9/2020      13112.0
# 75008      ZWE    Africa              Zimbabwe    9/9/2020       7429.0
#
#        new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 0           10.0        1475.0         1.0                 1019.900
# 1          215.0         218.0         6.0                  190.043
# 2          165.0         416.0         3.0                 5292.585
# 3            0.0          55.0         0.0                34892.901
# 4         1129.0         443.0         1.0                10629.803
# ...          ...           ...         ...                      ...
# 75004        5.0          35.0         0.0                   10.880
# 75005        5.0         576.0         0.0                   67.022
# 75006     1990.0       15168.0        82.0                10831.988
# 75007      160.0         300.0         3.0                  713.231
# 75008       41.0         222.0         4.0                  499.834
#
#        new_cases_per_million  ...  aged_65_older  aged_70_older  \
# 0                      0.257  ...          2.581          1.337
# 1                      6.542  ...          2.405          1.362
# 2                     57.335  ...         13.188          8.643
# 3                      0.000  ...            NaN            NaN
# 4                    114.151  ...          1.144          0.526
# ...                      ...  ...            ...            ...
# 75004                  0.051  ...          7.150          4.718
# 75005                  0.168  ...          2.922          1.583
# 75006                 33.553  ...          5.344          3.053
# 75007                  8.703  ...          2.480          1.542
# 75008                  2.759  ...          2.822          1.882
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            5819.495              NaN                276.045
# 2           11803.431              1.1                304.195
# 3                 NaN              NaN                109.135
# 4           67293.483              NaN                317.840
# ...               ...              ...                    ...
# 75004        6171.884              2.0                245.465
# 75005        1479.147             18.8                495.003
# 75006       12294.876             18.9                200.380
# 75007        3689.251             57.5                234.499
# 75008        1899.775             21.4                307.846
#
#        diabetes_prevalence  hospital_beds_per_thousand  life_expectancy  \
# 0                     9.59                        0.50            64.83
# 1                     3.94                         NaN            61.15
# 2                    10.08                        2.89            78.57
# 3                     7.97                         NaN            83.73
# 4                    17.26                        1.20            77.97
# ...                    ...                         ...              ...
# 75004                 6.00                        2.60            75.40
# 75005                 5.35                        0.70            66.12
# 75006                 5.52                        2.32            64.13
# 75007                 3.94                        2.00            63.89
# 75008                 1.82                        1.70            61.49
#
#        human_development_index  school_closures
# 0                        0.511                1
# 1                        0.581                2
# 2                        0.795                2
# 3                        0.868                1
# 4                        0.890                1
# ...                        ...              ...
# 75004                    0.704                3
# 75005                    0.470                2
# 75006                    0.709                1
# 75007                    0.584                2
# 75008                    0.571                3
#
# [75009 rows x 41 columns]

# %%
data = pd.read_sql('SELECT cd.*, sc.school_closures FROM coviddatah cd INNER JOIN  schoolclosuresh sc ON  sc.date = cd.date AND sc.iso_code = cd.iso_code',con=engine)
data
# Out:
#       iso_code continent              location        date  total_cases  \
# 0          AFG      Asia           Afghanistan  10/10/2020      39703.0
# 1          AGO    Africa                Angola  10/10/2020       6246.0
# 2          ALB    Europe               Albania  10/10/2020      15231.0
# 3          AND    Europe               Andorra  10/10/2020       2696.0
# 4          ARE      Asia  United Arab Emirates  10/10/2020     105133.0
# ...        ...       ...                   ...         ...          ...
# 75004      VNM      Asia               Vietnam    9/9/2020       1059.0
# 75005      YEM      Asia                 Yemen    9/9/2020       1999.0
# 75006      ZAF    Africa          South Africa    9/9/2020     642431.0
# 75007      ZMB    Africa                Zambia    9/9/2020      13112.0
# 75008      ZWE    Africa              Zimbabwe    9/9/2020       7429.0
#
#        new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 0           10.0        1475.0         1.0                 1019.900
# 1          215.0         218.0         6.0                  190.043
# 2          165.0         416.0         3.0                 5292.585
# 3            0.0          55.0         0.0                34892.901
# 4         1129.0         443.0         1.0                10629.803
# ...          ...           ...         ...                      ...
# 75004        5.0          35.0         0.0                   10.880
# 75005        5.0         576.0         0.0                   67.022
# 75006     1990.0       15168.0        82.0                10831.988
# 75007      160.0         300.0         3.0                  713.231
# 75008       41.0         222.0         4.0                  499.834
#
#        new_cases_per_million  ...  aged_65_older  aged_70_older  \
# 0                      0.257  ...          2.581          1.337
# 1                      6.542  ...          2.405          1.362
# 2                     57.335  ...         13.188          8.643
# 3                      0.000  ...            NaN            NaN
# 4                    114.151  ...          1.144          0.526
# ...                      ...  ...            ...            ...
# 75004                  0.051  ...          7.150          4.718
# 75005                  0.168  ...          2.922          1.583
# 75006                 33.553  ...          5.344          3.053
# 75007                  8.703  ...          2.480          1.542
# 75008                  2.759  ...          2.822          1.882
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            5819.495              NaN                276.045
# 2           11803.431              1.1                304.195
# 3                 NaN              NaN                109.135
# 4           67293.483              NaN                317.840
# ...               ...              ...                    ...
# 75004        6171.884              2.0                245.465
# 75005        1479.147             18.8                495.003
# 75006       12294.876             18.9                200.380
# 75007        3689.251             57.5                234.499
# 75008        1899.775             21.4                307.846
#
#        diabetes_prevalence  hospital_beds_per_thousand  life_expectancy  \
# 0                     9.59                        0.50            64.83
# 1                     3.94                         NaN            61.15
# 2                    10.08                        2.89            78.57
# 3                     7.97                         NaN            83.73
# 4                    17.26                        1.20            77.97
# ...                    ...                         ...              ...
# 75004                 6.00                        2.60            75.40
# 75005                 5.35                        0.70            66.12
# 75006                 5.52                        2.32            64.13
# 75007                 3.94                        2.00            63.89
# 75008                 1.82                        1.70            61.49
#
#        human_development_index  school_closures
# 0                        0.511                1
# 1                        0.581                2
# 2                        0.795                2
# 3                        0.868                1
# 4                        0.890                1
# ...                        ...              ...
# 75004                    0.704                3
# 75005                    0.470                2
# 75006                    0.709                1
# 75007                    0.584                2
# 75008                    0.571                3
#
# [75009 rows x 41 columns]

# %%
data.to_csv("data.csv")

# %%
small_data = data[["date", "location", "total_cases", "school_closures"]]
small_data
# Out:
#              date              location  total_cases  school_closures
# 0      10/10/2020           Afghanistan      39703.0                1
# 1      10/10/2020                Angola       6246.0                2
# 2      10/10/2020               Albania      15231.0                2
# 3      10/10/2020               Andorra       2696.0                1
# 4      10/10/2020  United Arab Emirates     105133.0                1
# ...           ...                   ...          ...              ...
# 75004    9/9/2020               Vietnam       1059.0                3
# 75005    9/9/2020                 Yemen       1999.0                2
# 75006    9/9/2020          South Africa     642431.0                1
# 75007    9/9/2020                Zambia      13112.0                2
# 75008    9/9/2020              Zimbabwe       7429.0                3
#
# [75009 rows x 4 columns]

# %%
stacked = small_data[["date", "total_cases", "school_closures"]].groupby(['date','school_closures']).agg('sum').reset_index()

stacked
# Out:
#            date  school_closures  total_cases
# 0      1/1/2021                0     292282.0
# 1      1/1/2021                1    4957988.0
# 2      1/1/2021                2   18975238.0
# 3      1/1/2021                3   59550117.0
# 4     1/10/2021                0     337301.0
# ...         ...              ...          ...
# 1832   9/8/2020                3   21735839.0
# 1833   9/9/2020                0     125363.0
# 1834   9/9/2020                1    2292816.0
# 1835   9/9/2020                2    3426453.0
# 1836   9/9/2020                3   21968760.0
#
# [1837 rows x 3 columns]

# %%
stacked_2 = stacked.fillna(0)
stacked_2
# Out:
#            date  school_closures  total_cases
# 0      1/1/2021                0     292282.0
# 1      1/1/2021                1    4957988.0
# 2      1/1/2021                2   18975238.0
# 3      1/1/2021                3   59550117.0
# 4     1/10/2021                0     337301.0
# ...         ...              ...          ...
# 1832   9/8/2020                3   21735839.0
# 1833   9/9/2020                0     125363.0
# 1834   9/9/2020                1    2292816.0
# 1835   9/9/2020                2    3426453.0
# 1836   9/9/2020                3   21968760.0
#
# [1837 rows x 3 columns]

# %%
datastacked_2.to_csv("stacked_2.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ff974edb929> in <module>
# ----> 1 datastacked_2.to_csv("stacked_2.csv")
#
# NameError: name 'datastacked_2' is not defined

# %%
data_melt = cases.pivot(index='date', columns='location')['total_cases']
data_melt
# Out:
# location   Afghanistan  Albania   Algeria  Andorra   Angola  Argentina  Aruba  \
# date
# 1/1/2021       51526.0  58316.0   99897.0   8117.0  17568.0  1629594.0    NaN
# 1/10/2021      53489.0  63595.0  102144.0   8586.0  18193.0  1722217.0    NaN
# 1/11/2021      53538.0  63971.0  102369.0   8586.0  18254.0  1730921.0    NaN
# 1/12/2021      53584.0  64627.0  102641.0   8682.0  18343.0  1744704.0    NaN
# 1/13/2021      53584.0  65334.0  102860.0   8818.0  18425.0  1757429.0    NaN
# ...                ...      ...       ...      ...      ...        ...    ...
# 9/5/2020       38324.0  10102.0   46071.0   1215.0   2935.0   471806.0    NaN
# 9/6/2020       38398.0  10255.0   46364.0   1215.0   2965.0   478792.0    NaN
# 9/7/2020       38494.0  10406.0   46653.0   1261.0   2981.0   488007.0    NaN
# 9/8/2020       38520.0  10553.0   46938.0   1261.0   3033.0   500034.0    NaN
# 9/9/2020       38544.0  10704.0   47216.0   1301.0   3092.0   512293.0    NaN
#
# location   Australia   Austria  Azerbaijan  ...  United Kingdom  \
# date                                        ...
# 1/1/2021     28460.0  362911.0    219041.0  ...       2549693.0
# 1/10/2021    28614.0  380722.0    224651.0  ...       3081372.0
# 1/11/2021    28634.0  382258.0    224827.0  ...       3127647.0
# 1/12/2021    28650.0  383833.0    225346.0  ...       3173295.0
# 1/13/2021    28660.0  385750.0    225820.0  ...       3220957.0
# ...              ...       ...         ...  ...             ...
# 9/5/2020     26278.0   29087.0     37192.0  ...        346513.0
# 9/6/2020     26321.0   29271.0     37329.0  ...        349500.0
# 9/7/2020     26373.0   29561.0     37418.0  ...        352453.0
# 9/8/2020     26465.0   30081.0     37557.0  ...        354934.0
# 9/9/2020     26524.0   30583.0     37732.0  ...        357615.0
#
# location   United States  Uruguay  Uzbekistan  Vanuatu  Venezuela  Vietnam  \
# date
# 1/1/2021      20252991.0  19753.0     77182.0      1.0   113884.0   1474.0
# 1/10/2021     22484332.0  26186.0     77572.0      1.0   116610.0   1514.0
# 1/11/2021     22699326.0  26901.0     77611.0      1.0   116983.0   1515.0
# 1/12/2021     22926246.0  27846.0     77663.0      1.0   117299.0   1520.0
# 1/13/2021     23156608.0  28475.0     77716.0      1.0   117811.0   1521.0
# ...                  ...      ...         ...      ...        ...      ...
# 9/5/2020       6247464.0   1669.0     43293.0      NaN    52165.0   1049.0
# 9/6/2020       6278633.0   1679.0     43587.0      NaN    53289.0   1049.0
# 9/7/2020       6302200.0   1693.0     43893.0      NaN    54350.0   1049.0
# 9/8/2020       6329593.0   1712.0     44281.0      NaN    55563.0   1054.0
# 9/9/2020       6363650.0   1741.0     44930.0      NaN    56751.0   1059.0
#
# location    Yemen   Zambia  Zimbabwe
# date
# 1/1/2021   2101.0  20997.0   14084.0
# 1/10/2021  2104.0  27728.0   21477.0
# 1/11/2021  2105.0  28596.0   22297.0
# 1/12/2021  2107.0  29757.0   23239.0
# 1/13/2021  2109.0  31100.0   24256.0
# ...           ...      ...       ...
# 9/5/2020   1983.0  12709.0    6837.0
# 9/6/2020   1987.0  12776.0    6837.0
# 9/7/2020   1989.0  12836.0    7298.0
# 9/8/2020   1994.0  12952.0    7388.0
# 9/9/2020   1999.0  13112.0    7429.0
#
# [478 rows x 180 columns]

# %%
data_melt.to_csv("data_melt.csv")
