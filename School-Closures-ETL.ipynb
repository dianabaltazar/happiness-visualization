# %%
import pandas as pd
from sqlalchemy import create_engine
from config import PostgresK

# %%
connection_string = f'postgres:{PostgresK}@localhost:5432/COVIDSchoolsClosures'
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['schoolclosures', 'coviddata']

# %%
print(engine)
# Out:
# Engine(postgresql://postgres:***@localhost:5432/COVIDSchoolsClosures)

# %%
pd.read_sql('SELECT * FROM schoolclosures', con=engine).head()
# Out:
#        country iso_code   obs_date  school_closures
# 0  Afghanistan      AFG  1/21/2020                0
# 1  Afghanistan      AFG  1/22/2020                0
# 2  Afghanistan      AFG  1/23/2020                0
# 3  Afghanistan      AFG  1/24/2020                0
# 4  Afghanistan      AFG  1/25/2020                0

# %%
pd.read_sql('SELECT * FROM coviddata', con=engine).head()
# Out:
#   iso_code continent geo_location   obs_date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020          1.0        1.0
# 1      AFG      Asia  Afghanistan  2/25/2020          1.0        0.0
# 2      AFG      Asia  Afghanistan  2/26/2020          1.0        0.0
# 3      AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 4      AFG      Asia  Afghanistan  2/28/2020          1.0        0.0
#
#    total_deaths  new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           NaN         NaN                    0.026                  0.026
# 1           NaN         NaN                    0.026                  0.000
# 2           NaN         NaN                    0.026                  0.000
# 3           NaN         NaN                    0.026                  0.000
# 4           NaN         NaN                    0.026                  0.000
#
#    ...  median_age  aged_65_older  aged_70_older  gdp_per_capita  \
# ...

# %%
pd.read_sql('SELECT cd.*, sc.school_closures FROM CovidData cd INNER JOIN  SchoolClosures sc ON  sc.obs_date = cd.obs_date AND sc.iso_code = cd.iso_code',con=engine)
# Out:
#       iso_code continent geo_location   obs_date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2/27/2020          1.0        0.0
# 1          AFG      Asia  Afghanistan  2/29/2020          1.0        0.0
# 2          AFG      Asia  Afghanistan   3/1/2020          1.0        0.0
# 3          AFG      Asia  Afghanistan   3/2/2020          1.0        0.0
# 4          AFG      Asia  Afghanistan   3/4/2020          4.0        2.0
# ...        ...       ...          ...        ...          ...        ...
# 75004      ZWE    Africa     Zimbabwe  4/28/2021      38191.0       27.0
# 75005      ZWE    Africa     Zimbabwe  4/30/2021      38257.0       22.0
# 75006      ZWE    Africa     Zimbabwe   5/6/2021      38398.0       41.0
# 75007      ZWE    Africa     Zimbabwe   5/8/2021      38414.0       11.0
# 75008      ZWE    Africa     Zimbabwe   5/9/2021      38419.0        5.0
#
#        total_deaths  new_deaths  total_cases_per_million  \
# ...
